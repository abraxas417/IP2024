# %% [markdown]
# Chap 1.3.1 Basic Operations on Images

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('minji.jpg',)

# %%
Plt_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(Plt_img, interpolation = 'bicubic')
plt.show()

# %%
img.shape
# Out:
# (259, 194, 3)

# %%
img[100,100]
# Out:
# array([ 0,  0, 27], dtype=uint8)

# %%
img[100,100,0]=0

# %%
img[100,100]=[0,0,0]

# %%
img[0:10,0:10]=[0,0,0]

# %%
cv2.namedWindow('image', cv2.WINDOW_NORMAL)
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imwrite('minji.jpg',img)
# Out:
# True

# %%
img[60:80,80:100]=[0,0,0]

# %%
px = img[100,100]
print px
[157 166 200]
# accessing only blue pixel
blue = img[60,80,0]
print blue
# Out:
#   Cell In[71], line 2
#     print px
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(px)?
