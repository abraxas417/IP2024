# %% [markdown]
# HOMEWORK3

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('dsu2.jpg')
rows,cols,ch = img.shape
pts1 = np.float32([[180,240],[820,222],[820,513],[180,500]])
pts2 = np.float32([[0,0],[900,0],[900,400],[0,400]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(900,400))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
# Out:
# (<Axes: title={'center': 'Output'}>,
#  <matplotlib.image.AxesImage at 0x28e84be37f0>,
#  Text(0.5, 1.0, 'Output'))
